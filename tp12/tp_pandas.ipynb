# %%
import numpy as np
import pandas as pd
from PersonDAO import PersonDAO

# %%
pd.Series([1, 3, 5, np.nan, 6, 8])
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.051695 -0.896984  1.403194  1.289259
# 2013-01-02  0.590502 -0.700099  0.324081 -0.596464
# 2013-01-03 -0.536445 -1.059863  1.509581  0.786824
# 2013-01-04  0.771545 -0.147288 -1.650512 -0.112385
# 2013-01-05 -0.649049  0.730209  0.718655 -1.270850
# 2013-01-06 -1.213813  0.485830 -0.176557 -0.111201

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=['Col 01','Col 02','Col 03','Col 04'])

# %%
df
# Out:
#               Col 01    Col 02    Col 03    Col 04
# 2013-01-01  0.407860 -0.226812  1.010764 -1.513767
# 2013-01-02 -1.017075  0.324279 -1.094471 -0.880876
# 2013-01-03  0.739581  0.110074  0.465197  1.905654
# 2013-01-04  0.755240  1.204450 -1.389506 -1.435150
# 2013-01-05 -1.525700 -1.056368 -1.412113  0.245400
# 2013-01-06  0.986926  0.624601 -1.077715  0.910453

# %%
df2 = pd.DataFrame(
    {

        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
dao = PersonDAO('persons.db')

# %%
df3 = pd.DataFrame(dao.findAll())
df3
# Out:
#        id first_name    last_name                           email  gender  \
# 0    6001       Isak         Buse               ibuse0@toplist.cz    Male
# 1    6002      Neila  Prendergast           nprendergast1@mtv.com  Female
# 2    6003       Skye     Hackford             shackford2@ucsd.edu    Male
# 3    6004     Dionne     Friedman           dfriedman3@oakley.com  Female
# 4    6005      Loria      Gasnell          lgasnell4@japanpost.jp  Female
# ..    ...        ...          ...                             ...     ...
# 995  6996       Abel         Alti           aaltirn@instagram.com    Male
# 996  6997     Lizzie      Mustard  lmustardro@businessinsider.com  Female
# 997  6998  Delphinia       Byrnes             dbyrnesrp@jigsy.com  Female
# 998  6999        Nev     Macauley     nmacauleyrq@accuweather.com    Male
# 999  7000     Fulvia        Gobel            fgobelrr@yahoo.co.jp  Female
#
#          ip_address
# 0      86.193.5.205
# 1       24.30.49.89
# ...

# %%
df3.head(2)
# Out:
#      id first_name    last_name                  email  gender    ip_address
# 0  6001       Isak         Buse      ibuse0@toplist.cz    Male  86.193.5.205
# 1  6002      Neila  Prendergast  nprendergast1@mtv.com  Female   24.30.49.89

# %%
df3.tail()
# Out:
#        id first_name last_name                           email  gender  \
# 995  6996       Abel      Alti           aaltirn@instagram.com    Male
# 996  6997     Lizzie   Mustard  lmustardro@businessinsider.com  Female
# 997  6998  Delphinia    Byrnes             dbyrnesrp@jigsy.com  Female
# 998  6999        Nev  Macauley     nmacauleyrq@accuweather.com    Male
# 999  7000     Fulvia     Gobel            fgobelrr@yahoo.co.jp  Female
#
#          ip_address
# 995  210.107.74.100
# 996      76.0.38.71
# 997  28.255.207.134
# 998  170.76.161.212
# 999  232.17.194.108

# %%
df3.describe()
# Out:
#                 id
# count  1000.000000
# mean   6500.500000
# std     288.819436
# min    6001.000000
# 25%    6250.750000
# 50%    6500.500000
# 75%    6750.250000
# max    7000.000000

# %%
df3['gender'].describe()
# Out:
# count       1000
# unique         8
# top       Female
# freq         449
# Name: gender, dtype: object

# %%
df3[df3['gender']=='Male'].describe()
# Out:
#                 id
# count   446.000000
# mean   6500.280269
# std     285.854941
# min    6001.000000
# 25%    6246.250000
# 50%    6511.500000
# 75%    6738.250000
# max    6999.000000

# %%
df3['upper_last_name'] = df3['last_name'].map(lambda l:l.upper())

# %%
df3
# Out:
#        id first_name    last_name                           email  gender  \
# 0    6001       Isak         Buse               ibuse0@toplist.cz    Male
# 1    6002      Neila  Prendergast           nprendergast1@mtv.com  Female
# 2    6003       Skye     Hackford             shackford2@ucsd.edu    Male
# 3    6004     Dionne     Friedman           dfriedman3@oakley.com  Female
# 4    6005      Loria      Gasnell          lgasnell4@japanpost.jp  Female
# ..    ...        ...          ...                             ...     ...
# 995  6996       Abel         Alti           aaltirn@instagram.com    Male
# 996  6997     Lizzie      Mustard  lmustardro@businessinsider.com  Female
# 997  6998  Delphinia       Byrnes             dbyrnesrp@jigsy.com  Female
# 998  6999        Nev     Macauley     nmacauleyrq@accuweather.com    Male
# 999  7000     Fulvia        Gobel            fgobelrr@yahoo.co.jp  Female
#
#          ip_address upper_last_name
# 0      86.193.5.205            BUSE
# ...

# %%
df3[["first_name","last_name","upper_last_name"]]
# Out:
#     first_name    last_name upper_last_name
# 0         Isak         Buse            BUSE
# 1        Neila  Prendergast     PRENDERGAST
# 2         Skye     Hackford        HACKFORD
# 3       Dionne     Friedman        FRIEDMAN
# 4        Loria      Gasnell         GASNELL
# ..         ...          ...             ...
# 995       Abel         Alti            ALTI
# 996     Lizzie      Mustard         MUSTARD
# 997  Delphinia       Byrnes          BYRNES
# 998        Nev     Macauley        MACAULEY
# 999     Fulvia        Gobel           GOBEL
#
# [1000 rows x 3 columns]

# %%
df3.iloc[1:3,[1,2]]
# Out:
#   first_name    last_name
# 1      Neila  Prendergast
# 2       Skye     Hackford

# %%
df3.loc[:,"first_name"]
# Out:
# 0           Isak
# 1          Neila
# 2           Skye
# 3         Dionne
# 4          Loria
#          ...
# 995         Abel
# 996       Lizzie
# 997    Delphinia
# 998          Nev
# 999       Fulvia
# Name: first_name, Length: 1000, dtype: object
